# %% [markdown]
# 실시간 도로 교통량 데이터
# json 파일을 dataframe으로 변환 해보기

# %%
import requests
import json
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'http://data.ex.co.kr/openapi/odtraffic/trafficAmountByCongest?key=7156795877&type=json'

# %%
result = requests.get(url,verify=False)
result.encoding = 'utf-8'
# text=result.text

# %%
text=result.text
text
data=json.loads(text)
data
# Out:
# {'list': [{'stdHour': '1608',
#    'routeNo': '0010',
#    'routeName': '경부선',
#    'updownTypeCode': 'E',
#    'vdsId': '0010VDE28900',
#    'trafficAmout': '119',
#    'shareRatio': '46',
#    'conzoneId': '0010CZE405',
#    'conzoneName': '남사진위IC-오산IC',
#    'stdDate': '20220816',
#    'speed': '33',
#    'timeAvg': '187',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0010',
#    'routeName': '경부선',
#    'updownTypeCode': 'E',
#    'vdsId': '0010VDE29000',
#    'trafficAmout': '112',
#    'shareRatio': '36',
#    'conzoneId': '0010CZE405',
#    'conzoneName': '남사진위IC-오산IC',
#    'stdDate': '20220816',
#    'speed': '37',
#    'timeAvg': '109',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0010',
#    'routeName': '경부선',
#    'updownTypeCode': 'E',
#    'vdsId': '0010VDE29200',
#    'trafficAmout': '67',
#    'shareRatio': '39',
#    'conzoneId': '0010CZE405',
#    'conzoneName': '남사진위IC-오산IC',
#    'stdDate': '20220816',
#    'speed': '35',
#    'timeAvg': '106',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0010',
#    'routeName': '경부선',
#    'updownTypeCode': 'E',
#    'vdsId': '0010VDE29300',
#    'trafficAmout': '96',
#    'shareRatio': '28',
#    'conzoneId': '0010CZE410',
#    'conzoneName': '오산IC-동탄JC',
#    'stdDate': '20220816',
#    'speed': '34',
#    'timeAvg': '139',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0010',
#    'routeName': '경부선',
#    'updownTypeCode': 'E',
#    'vdsId': '0010VDE29400',
#    'trafficAmout': '96',
#    'shareRatio': '28',
#    'conzoneId': '0010CZE410',
#    'conzoneName': '오산IC-동탄JC',
#    'stdDate': '20220816',
#    'speed': '34',
#    'timeAvg': '89',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0010',
#    'routeName': '경부선',
#    'updownTypeCode': 'E',
#    'vdsId': '0010VDE30400',
#    'trafficAmout': '73',
#    'shareRatio': '16',
#    'conzoneId': '0010CZE450',
#    'conzoneName': '수원신갈IC-신갈JC',
#    'stdDate': '20220816',
#    'speed': '20',
#    'timeAvg': '98',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0010',
#    'routeName': '경부선',
#    'updownTypeCode': 'E',
#    'vdsId': '0010VDE30450',
#    'trafficAmout': '48',
#    'shareRatio': '28',
#    'conzoneId': '0010CZE450',
#    'conzoneName': '수원신갈IC-신갈JC',
#    'stdDate': '20220816',
#    'speed': '20',
#    'timeAvg': '132',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0010',
#    'routeName': '경부선',
#    'updownTypeCode': 'E',
#    'vdsId': '0010VDE30500',
#    'trafficAmout': '67',
#    'shareRatio': '13',
#    'conzoneId': '0010CZE450',
#    'conzoneName': '수원신갈IC-신갈JC',
#    'stdDate': '20220816',
#    'speed': '24',
#    'timeAvg': '202',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0010',
#    'routeName': '경부선',
#    'updownTypeCode': 'E',
#    'vdsId': '0010VDE30600',
#    'trafficAmout': '23',
#    'shareRatio': '6',
#    'conzoneId': '0010CZE460',
#    'conzoneName': '신갈JC-서울TG',
#    'stdDate': '20220816',
#    'speed': '15',
#    'timeAvg': '148',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0010',
#    'routeName': '경부선',
#    'updownTypeCode': 'E',
#    'vdsId': '0010VDE30632',
#    'trafficAmout': '45',
#    'shareRatio': '8',
#    'conzoneId': '0010CZE460',
#    'conzoneName': '신갈JC-서울TG',
#    'stdDate': '20220816',
#    'speed': '30',
#    'timeAvg': '119',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0010',
#    'routeName': '경부선',
#    'updownTypeCode': 'E',
#    'vdsId': '0010VDE32250',
#    'trafficAmout': '40',
#    'shareRatio': '31',
#    'conzoneId': '0010CZE505',
#    'conzoneName': '금토JC-양재IC',
#    'stdDate': '20220816',
#    'speed': '38',
#    'timeAvg': '97',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0010',
#    'routeName': '경부선',
#    'updownTypeCode': 'E',
#    'vdsId': '0010VDE32350',
#    'trafficAmout': '43',
#    'shareRatio': '56',
#    'conzoneId': '0010CZE505',
#    'conzoneName': '금토JC-양재IC',
#    'stdDate': '20220816',
#    'speed': '22',
#    'timeAvg': '203',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0010',
#    'routeName': '경부선',
#    'updownTypeCode': 'S',
#    'vdsId': '0010VDS30500',
#    'trafficAmout': '109',
#    'shareRatio': '12',
#    'conzoneId': '0010CZS450',
#    'conzoneName': '신갈JC-수원신갈IC',
#    'stdDate': '20220816',
#    'speed': '37',
#    'timeAvg': '130',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0100',
#    'routeName': '남해선(순천-부산)',
#    'updownTypeCode': 'E',
#    'vdsId': '0100VDE10400',
#    'trafficAmout': '15',
#    'shareRatio': '9',
#    'conzoneId': '0100CZE205',
#    'conzoneName': '칠원JC - 창원1터널(서측)',
#    'stdDate': '20220816',
#    'speed': '38',
#    'timeAvg': '185',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0100',
#    'routeName': '남해선(순천-부산)',
#    'updownTypeCode': 'E',
#    'vdsId': '0100VDE10600',
#    'trafficAmout': '31',
#    'shareRatio': '41',
#    'conzoneId': '0100CZE205',
#    'conzoneName': '칠원JC - 창원1터널(서측)',
#    'stdDate': '20220816',
#    'speed': '21',
#    'timeAvg': '328',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0150',
#    'routeName': '서해안선',
#    'updownTypeCode': 'E',
#    'vdsId': '0150VDE26600',
#    'trafficAmout': '61',
#    'shareRatio': '4',
#    'conzoneId': '0150CZE290',
#    'conzoneName': '서평택JC-발안IC',
#    'stdDate': '20220816',
#    'speed': '27',
#    'timeAvg': '156',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0150',
#    'routeName': '서해안선',
#    'updownTypeCode': 'E',
#    'vdsId': '0150VDE26700',
#    'trafficAmout': '61',
#    'shareRatio': '4',
#    'conzoneId': '0150CZE290',
#    'conzoneName': '서평택JC-발안IC',
#    'stdDate': '20220816',
#    'speed': '27',
#    'timeAvg': '156',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0150',
#    'routeName': '서해안선',
#    'updownTypeCode': 'E',
#    'vdsId': '0150VDE27000',
#    'trafficAmout': '66',
#    'shareRatio': '31',
#    'conzoneId': '0150CZE300',
#    'conzoneName': '발안IC-팔탄JC',
#    'stdDate': '20220816',
#    'speed': '33',
#    'timeAvg': '278',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0150',
#    'routeName': '서해안선',
#    'updownTypeCode': 'E',
#    'vdsId': '0150VDE27100',
#    'trafficAmout': '66',
#    'shareRatio': '31',
#    'conzoneId': '0150CZE300',
#    'conzoneName': '발안IC-팔탄JC',
#    'stdDate': '20220816',
#    'speed': '33',
#    'timeAvg': '159',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0150',
#    'routeName': '서해안선',
#    'updownTypeCode': 'E',
#    'vdsId': '0150VDE29010',
#    'trafficAmout': '47',
#    'shareRatio': '37',
#    'conzoneId': '0150CZE370',
#    'conzoneName': '광명역IC-일직JC',
#    'stdDate': '20220816',
#    'speed': '28',
#    'timeAvg': '133',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0150',
#    'routeName': '서해안선',
#    'updownTypeCode': 'E',
#    'vdsId': '0150VDE29410',
#    'trafficAmout': '49',
#    'shareRatio': '38',
#    'conzoneId': '0150CZE380',
#    'conzoneName': '일직JC-금천IC',
#    'stdDate': '20220816',
#    'speed': '24',
#    'timeAvg': '95',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0150',
#    'routeName': '서해안선',
#    'updownTypeCode': 'E',
#    'vdsId': '0150VDE29500',
#    'trafficAmout': '49',
#    'shareRatio': '38',
#    'conzoneId': '0150CZE380',
#    'conzoneName': '일직JC-금천IC',
#    'stdDate': '20220816',
#    'speed': '24',
#    'timeAvg': '274',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0153',
#    'routeName': '평택시흥선',
#    'updownTypeCode': 'E',
#    'vdsId': '0153VDE00220',
#    'trafficAmout': '26',
#    'shareRatio': '10',
#    'conzoneId': '0153CZE030',
#    'conzoneName': '송산마도IC-남안산IC',
#    'stdDate': '20220816',
#    'speed': '12',
#    'timeAvg': '356',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0153',
#    'routeName': '평택시흥선',
#    'updownTypeCode': 'E',
#    'vdsId': '0153VDE00240',
#    'trafficAmout': '42',
#    'shareRatio': '3',
#    'conzoneId': '0153CZE030',
#    'conzoneName': '송산마도IC-남안산IC',
#    'stdDate': '20220816',
#    'speed': '35',
#    'timeAvg': '85',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0153',
#    'routeName': '평택시흥선',
#    'updownTypeCode': 'E',
#    'vdsId': '0153VDE00250',
#    'trafficAmout': '36',
#    'shareRatio': '3',
#    'conzoneId': '0153CZE030',
#    'conzoneName': '송산마도IC-남안산IC',
#    'stdDate': '20220816',
#    'speed': '37',
#    'timeAvg': '97',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0153',
#    'routeName': '평택시흥선',
#    'updownTypeCode': 'E',
#    'vdsId': '0153VDE00270',
#    'trafficAmout': '36',
#    'shareRatio': '4',
#    'conzoneId': '0153CZE030',
#    'conzoneName': '송산마도IC-남안산IC',
#    'stdDate': '20220816',
#    'speed': '37',
#    'timeAvg': '124',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0170',
#    'routeName': '평택화성선',
#    'updownTypeCode': 'E',
#    'vdsId': '0170VDE00012',
#    'trafficAmout': '47',
#    'shareRatio': '23',
#    'conzoneId': '0170CZE040',
#    'conzoneName': '북평택TG-향남IC',
#    'stdDate': '20220816',
#    'speed': '35',
#    'timeAvg': '96',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0170',
#    'routeName': '평택화성선',
#    'updownTypeCode': 'E',
#    'vdsId': '0170VDE00013',
#    'trafficAmout': '65',
#    'shareRatio': '22',
#    'conzoneId': '0170CZE040',
#    'conzoneName': '북평택TG-향남IC',
#    'stdDate': '20220816',
#    'speed': '28',
#    'timeAvg': '163',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0170',
#    'routeName': '평택화성선',
#    'updownTypeCode': 'E',
#    'vdsId': '0170VDE00014',
#    'trafficAmout': '57',
#    'shareRatio': '23',
#    'conzoneId': '0170CZE050',
#    'conzoneName': '향남IC-서오산JC',
#    'stdDate': '20220816',
#    'speed': '29',
#    'timeAvg': '90',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0170',
#    'routeName': '평택화성선',
#    'updownTypeCode': 'E',
#    'vdsId': '0170VDE00015',
#    'trafficAmout': '35',
#    'shareRatio': '25',
#    'conzoneId': '0170CZE050',
#    'conzoneName': '향남IC-서오산JC',
#    'stdDate': '20220816',
#    'speed': '26',
#    'timeAvg': '137',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0170',
#    'routeName': '평택화성선',
#    'updownTypeCode': 'E',
#    'vdsId': '0170VDE00016',
#    'trafficAmout': '63',
#    'shareRatio': '24',
#    'conzoneId': '0170CZE050',
#    'conzoneName': '향남IC-서오산JC',
#    'stdDate': '20220816',
#    'speed': '37',
#    'timeAvg': '101',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0170',
#    'routeName': '평택화성선',
#    'updownTypeCode': 'E',
#    'vdsId': '0170VDE00024',
#    'trafficAmout': '68',
#    'shareRatio': '27',
#    'conzoneId': '0170CZE075',
#    'conzoneName': '화성JC-봉담TG',
#    'stdDate': '20220816',
#    'speed': '36',
#    'timeAvg': '84',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0170',
#    'routeName': '평택화성선',
#    'updownTypeCode': 'E',
#    'vdsId': '0170VDE00025',
#    'trafficAmout': '61',
#    'shareRatio': '35',
#    'conzoneId': '0170CZE075',
#    'conzoneName': '화성JC-봉담TG',
#    'stdDate': '20220816',
#    'speed': '28',
#    'timeAvg': '142',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0170',
#    'routeName': '평택화성선',
#    'updownTypeCode': 'E',
#    'vdsId': '0170VDE00090',
#    'trafficAmout': '30',
#    'shareRatio': '21',
#    'conzoneId': '0170CZE110',
#    'conzoneName': '봉담IC-금곡IC',
#    'stdDate': '20220816',
#    'speed': '23',
#    'timeAvg': '149',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0170',
#    'routeName': '평택화성선',
#    'updownTypeCode': 'E',
#    'vdsId': '0170VDE00100',
#    'trafficAmout': '22',
#    'shareRatio': '53',
#    'conzoneId': '0170CZE110',
#    'conzoneName': '봉담IC-금곡IC',
#    'stdDate': '20220816',
#    'speed': '9',
#    'timeAvg': '534',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0170',
#    'routeName': '평택화성선',
#    'updownTypeCode': 'E',
#    'vdsId': '0170VDE00110',
#    'trafficAmout': '35',
#    'shareRatio': '45',
#    'conzoneId': '0170CZE110',
#    'conzoneName': '봉담IC-금곡IC',
#    'stdDate': '20220816',
#    'speed': '19',
#    'timeAvg': '109',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0170',
#    'routeName': '평택화성선',
#    'updownTypeCode': 'E',
#    'vdsId': '0170VDE00120',
#    'trafficAmout': '33',
#    'shareRatio': '49',
#    'conzoneId': '0170CZE120',
#    'conzoneName': '금곡IC-동안산IC',
#    'stdDate': '20220816',
#    'speed': '13',
#    'timeAvg': '310',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0170',
#    'routeName': '평택화성선',
#    'updownTypeCode': 'E',
#    'vdsId': '0170VDE00130',
#    'trafficAmout': '36',
#    'shareRatio': '63',
#    'conzoneId': '0170CZE130',
#    'conzoneName': '동안산IC-남군포IC',
#    'stdDate': '20220816',
#    'speed': '20',
#    'timeAvg': '106',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0170',
#    'routeName': '평택화성선',
#    'updownTypeCode': 'E',
#    'vdsId': '0170VDE00140',
#    'trafficAmout': '47',
#    'shareRatio': '24',
#    'conzoneId': '0170CZE130',
#    'conzoneName': '동안산IC-남군포IC',
#    'stdDate': '20220816',
#    'speed': '32',
#    'timeAvg': '67',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0252',
#    'routeName': '논산천안선',
#    'updownTypeCode': 'E',
#    'vdsId': '0252VDE19000',
#    'trafficAmout': '39',
#    'shareRatio': '28',
#    'conzoneId': '0252CZE080',
#    'conzoneName': '정안IC-남풍세IC',
#    'stdDate': '20220816',
#    'speed': '32',
#    'timeAvg': '91',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0252',
#    'routeName': '논산천안선',
#    'updownTypeCode': 'E',
#    'vdsId': '0252VDE19010',
#    'trafficAmout': '43',
#    'shareRatio': '34',
#    'conzoneId': '0252CZE080',
#    'conzoneName': '정안IC-남풍세IC',
#    'stdDate': '20220816',
#    'speed': '27',
#    'timeAvg': '88',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0252',
#    'routeName': '논산천안선',
#    'updownTypeCode': 'E',
#    'vdsId': '0252VDE19020',
#    'trafficAmout': '47',
#    'shareRatio': '30',
#    'conzoneId': '0252CZE080',
#    'conzoneName': '정안IC-남풍세IC',
#    'stdDate': '20220816',
#    'speed': '34',
#    'timeAvg': '97',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0252',
#    'routeName': '논산천안선',
#    'updownTypeCode': 'E',
#    'vdsId': '0252VDE19050',
#    'trafficAmout': '40',
#    'shareRatio': '22',
#    'conzoneId': '0252CZE080',
#    'conzoneName': '정안IC-남풍세IC',
#    'stdDate': '20220816',
#    'speed': '39',
#    'timeAvg': '88',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0351',
#    'routeName': '통영대전선',
#    'updownTypeCode': 'E',
#    'vdsId': '0351VDE16900',
#    'trafficAmout': '7',
#    'shareRatio': '21',
#    'conzoneId': '0351CZE180',
#    'conzoneName': '추부IC-남대전IC',
#    'stdDate': '20220816',
#    'speed': '5',
#    'timeAvg': '3331',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0351',
#    'routeName': '통영대전선',
#    'updownTypeCode': 'S',
#    'vdsId': '0351VDS18100',
#    'trafficAmout': '18',
#    'shareRatio': '18',
#    'conzoneId': '0351CZS210',
#    'conzoneName': '비룡JC-판암IC',
#    'stdDate': '20220816',
#    'speed': '27',
#    'timeAvg': '31',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0352',
#    'routeName': '중부선',
#    'updownTypeCode': 'E',
#    'vdsId': '0352VDE02400',
#    'trafficAmout': '16',
#    'shareRatio': '2',
#    'conzoneId': '0352CZE310',
#    'conzoneName': '증평IC-진천IC',
#    'stdDate': '20220816',
#    'speed': '7',
#    'timeAvg': '533',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0352',
#    'routeName': '중부선',
#    'updownTypeCode': 'E',
#    'vdsId': '0352VDE02500',
#    'trafficAmout': '30',
#    'shareRatio': '30',
#    'conzoneId': '0352CZE310',
#    'conzoneName': '증평IC-진천IC',
#    'stdDate': '20220816',
#    'speed': '21',
#    'timeAvg': '167',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0352',
#    'routeName': '중부선',
#    'updownTypeCode': 'E',
#    'vdsId': '0352VDE03000',
#    'trafficAmout': '45',
#    'shareRatio': '35',
#    'conzoneId': '0352CZE310',
#    'conzoneName': '증평IC-진천IC',
#    'stdDate': '20220816',
#    'speed': '33',
#    'timeAvg': '111',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0352',
#    'routeName': '중부선',
#    'updownTypeCode': 'E',
#    'vdsId': '0352VDE06000',
#    'trafficAmout': '33',
#    'shareRatio': '28',
#    'conzoneId': '0352CZE345',
#    'conzoneName': '삼성Hi-일죽IC',
#    'stdDate': '20220816',
#    'speed': '27',
#    'timeAvg': '99',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0352',
#    'routeName': '중부선',
#    'updownTypeCode': 'E',
#    'vdsId': '0352VDE06100',
#    'trafficAmout': '43',
#    'shareRatio': '23',
#    'conzoneId': '0352CZE350',
#    'conzoneName': '일죽IC-남이천IC',
#    'stdDate': '20220816',
#    'speed': '31',
#    'timeAvg': '183',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0352',
#    'routeName': '중부선',
#    'updownTypeCode': 'E',
#    'vdsId': '0352VDE10300',
#    'trafficAmout': '60',
#    'shareRatio': '45',
#    'conzoneId': '0352CZE430',
#    'conzoneName': '하남IC-하남JC',
#    'stdDate': '20220816',
#    'speed': '17',
#    'timeAvg': '196',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0370',
#    'routeName': '제2중부선',
#    'updownTypeCode': 'E',
#    'vdsId': '0370VDE01900',
#    'trafficAmout': '38',
#    'shareRatio': '27',
#    'conzoneId': '0370CZE040',
#    'conzoneName': '신월천교-천진암교',
#    'stdDate': '20220816',
#    'speed': '27',
#    'timeAvg': '317',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0450',
#    'routeName': '중부내륙선',
#    'updownTypeCode': 'E',
#    'vdsId': '0450VDE18900',
#    'trafficAmout': '43',
#    'shareRatio': '26',
#    'conzoneId': '0450CZE210',
#    'conzoneName': '충주IC-중앙탑Hi',
#    'stdDate': '20220816',
#    'speed': '40',
#    'timeAvg': '120',
#    'grade': '2'},
#   {'stdHour': '1608',
#    'routeNo': '0450',
#    'routeName': '중부내륙선',
#    'updownTypeCode': 'E',
#    'vdsId': '0450VDE19100',
#    'trafficAmout': '44',
#    'shareRatio': '32',
#    'conzoneId': '0450CZE215',
#    'conzoneName': '중앙탑Hi-북충주IC',
#    'stdDate': '20220816',
#    'speed': '34',
#    'timeAvg': '150',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0500',
#    'routeName': '영동선',
#    'updownTypeCode': 'E',
#    'vdsId': '0500VDE14500',
#    'trafficAmout': '9',
#    'shareRatio': '39',
#    'conzoneId': '0500CZE250',
#    'conzoneName': '둔내IC-동둔내Hi',
#    'stdDate': '20220816',
#    'speed': '5',
#    'timeAvg': '604',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0500',
#    'routeName': '영동선',
#    'updownTypeCode': 'E',
#    'vdsId': '0500VDE14551',
#    'trafficAmout': '19',
#    'shareRatio': '17',
#    'conzoneId': '0500CZE250',
#    'conzoneName': '둔내IC-동둔내Hi',
#    'stdDate': '20220816',
#    'speed': '19',
#    'timeAvg': '263',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0500',
#    'routeName': '영동선',
#    'updownTypeCode': 'E',
#    'vdsId': '0500VDE14602',
#    'trafficAmout': '20',
#    'shareRatio': '19',
#    'conzoneId': '0500CZE255',
#    'conzoneName': '동둔내Hi-면온IC',
#    'stdDate': '20220816',
#    'speed': '18',
#    'timeAvg': '121',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0500',
#    'routeName': '영동선',
#    'updownTypeCode': 'E',
#    'vdsId': '0500VDE18202',
#    'trafficAmout': '18',
#    'shareRatio': '13',
#    'conzoneId': '0500CZE300',
#    'conzoneName': '대관령IC-강릉JC',
#    'stdDate': '20220816',
#    'speed': '23',
#    'timeAvg': '84',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0500',
#    'routeName': '영동선',
#    'updownTypeCode': 'S',
#    'vdsId': '0500VDS00400',
#    'trafficAmout': '65',
#    'shareRatio': '41',
#    'conzoneId': '0500CZS010',
#    'conzoneName': '월곶JC-서창JC',
#    'stdDate': '20220816',
#    'speed': '31',
#    'timeAvg': '97',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0500',
#    'routeName': '영동선',
#    'updownTypeCode': 'S',
#    'vdsId': '0500VDS00500',
#    'trafficAmout': '13',
#    'shareRatio': '7',
#    'conzoneId': '0500CZS020',
#    'conzoneName': '군자TG-월곶JC',
#    'stdDate': '20220816',
#    'speed': '12',
#    'timeAvg': '860',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0500',
#    'routeName': '영동선',
#    'updownTypeCode': 'S',
#    'vdsId': '0500VDS00700',
#    'trafficAmout': '37',
#    'shareRatio': '12',
#    'conzoneId': '0500CZS025',
#    'conzoneName': '군자TG-군자JC',
#    'stdDate': '20220816',
#    'speed': '18',
#    'timeAvg': '254',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0500',
#    'routeName': '영동선',
#    'updownTypeCode': 'S',
#    'vdsId': '0500VDS00800',
#    'trafficAmout': '25',
#    'shareRatio': '50',
#    'conzoneId': '0500CZS025',
#    'conzoneName': '군자TG-군자JC',
#    'stdDate': '20220816',
#    'speed': '22',
#    'timeAvg': '120',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0500',
#    'routeName': '영동선',
#    'updownTypeCode': 'S',
#    'vdsId': '0500VDS01600',
#    'trafficAmout': '67',
#    'shareRatio': '25',
#    'conzoneId': '0500CZS060',
#    'conzoneName': '둔대JC-안산JC',
#    'stdDate': '20220816',
#    'speed': '39',
#    'timeAvg': '22',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0500',
#    'routeName': '영동선',
#    'updownTypeCode': 'S',
#    'vdsId': '0500VDS01651',
#    'trafficAmout': '66',
#    'shareRatio': '0',
#    'conzoneId': '0500CZS060',
#    'conzoneName': '둔대JC-안산JC',
#    'stdDate': '20220816',
#    'speed': '32',
#    'timeAvg': '72',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0500',
#    'routeName': '영동선',
#    'updownTypeCode': 'S',
#    'vdsId': '0500VDS01700',
#    'trafficAmout': '67',
#    'shareRatio': '25',
#    'conzoneId': '0500CZS060',
#    'conzoneName': '둔대JC-안산JC',
#    'stdDate': '20220816',
#    'speed': '39',
#    'timeAvg': '50',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0500',
#    'routeName': '영동선',
#    'updownTypeCode': 'S',
#    'vdsId': '0500VDS02200',
#    'trafficAmout': '67',
#    'shareRatio': '28',
#    'conzoneId': '0500CZS080',
#    'conzoneName': '부곡IC-동군포IC',
#    'stdDate': '20220816',
#    'speed': '30',
#    'timeAvg': '144',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0500',
#    'routeName': '영동선',
#    'updownTypeCode': 'S',
#    'vdsId': '0500VDS02300',
#    'trafficAmout': '67',
#    'shareRatio': '28',
#    'conzoneId': '0500CZS080',
#    'conzoneName': '부곡IC-동군포IC',
#    'stdDate': '20220816',
#    'speed': '30',
#    'timeAvg': '105',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0500',
#    'routeName': '영동선',
#    'updownTypeCode': 'S',
#    'vdsId': '0500VDS02952',
#    'trafficAmout': '77',
#    'shareRatio': '0',
#    'conzoneId': '0500CZS100',
#    'conzoneName': '동수원IC-북수원IC',
#    'stdDate': '20220816',
#    'speed': '28',
#    'timeAvg': '12',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0500',
#    'routeName': '영동선',
#    'updownTypeCode': 'S',
#    'vdsId': '0500VDS03000',
#    'trafficAmout': '77',
#    'shareRatio': '0',
#    'conzoneId': '0500CZS100',
#    'conzoneName': '동수원IC-북수원IC',
#    'stdDate': '20220816',
#    'speed': '28',
#    'timeAvg': '61',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0500',
#    'routeName': '영동선',
#    'updownTypeCode': 'S',
#    'vdsId': '0500VDS03100',
#    'trafficAmout': '73',
#    'shareRatio': '0',
#    'conzoneId': '0500CZS100',
#    'conzoneName': '동수원IC-북수원IC',
#    'stdDate': '20220816',
#    'speed': '19',
#    'timeAvg': '201',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0500',
#    'routeName': '영동선',
#    'updownTypeCode': 'S',
#    'vdsId': '0500VDS03200',
#    'trafficAmout': '82',
#    'shareRatio': '39',
#    'conzoneId': '0500CZS110',
#    'conzoneName': '신갈JC-동수원IC',
#    'stdDate': '20220816',
#    'speed': '28',
#    'timeAvg': '136',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0500',
#    'routeName': '영동선',
#    'updownTypeCode': 'S',
#    'vdsId': '0500VDS04107',
#    'trafficAmout': '34',
#    'shareRatio': '27',
#    'conzoneId': '0500CZS130',
#    'conzoneName': '서용인JC-마성IC',
#    'stdDate': '20220816',
#    'speed': '20',
#    'timeAvg': '84',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0500',
#    'routeName': '영동선',
#    'updownTypeCode': 'S',
#    'vdsId': '0500VDS05103',
#    'trafficAmout': '45',
#    'shareRatio': '22',
#    'conzoneId': '0500CZS140',
#    'conzoneName': '양지IC-용인IC',
#    'stdDate': '20220816',
#    'speed': '36',
#    'timeAvg': '53',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0520',
#    'routeName': '광주원주선',
#    'updownTypeCode': 'S',
#    'vdsId': '0520VDS00800',
#    'trafficAmout': '42',
#    'shareRatio': '25',
#    'conzoneId': '0520CZS100',
#    'conzoneName': '동곤지암IC-곤지암1터널',
#    'stdDate': '20220816',
#    'speed': '28',
#    'timeAvg': '111',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0520',
#    'routeName': '광주원주선',
#    'updownTypeCode': 'S',
#    'vdsId': '0520VDS01100',
#    'trafficAmout': '12',
#    'shareRatio': '55',
#    'conzoneId': '0520CZS110',
#    'conzoneName': '흥천이포IC-동곤지암IC',
#    'stdDate': '20220816',
#    'speed': '6',
#    'timeAvg': '456',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0520',
#    'routeName': '광주원주선',
#    'updownTypeCode': 'S',
#    'vdsId': '0520VDS01200',
#    'trafficAmout': '20',
#    'shareRatio': '35',
#    'conzoneId': '0520CZS110',
#    'conzoneName': '흥천이포IC-동곤지암IC',
#    'stdDate': '20220816',
#    'speed': '11',
#    'timeAvg': '330',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0520',
#    'routeName': '광주원주선',
#    'updownTypeCode': 'S',
#    'vdsId': '0520VDS02000',
#    'trafficAmout': '34',
#    'shareRatio': '16',
#    'conzoneId': '0520CZS110',
#    'conzoneName': '흥천이포IC-동곤지암IC',
#    'stdDate': '20220816',
#    'speed': '40',
#    'timeAvg': '133',
#    'grade': '2'},
#   {'stdHour': '1608',
#    'routeNo': '0600',
#    'routeName': '서울양양선',
#    'updownTypeCode': 'S',
#    'vdsId': '0600VDS00001',
#    'trafficAmout': '49',
#    'shareRatio': '29',
#    'conzoneId': '0600CZS020',
#    'conzoneName': '미사IC-선동IC',
#    'stdDate': '20220816',
#    'speed': '31',
#    'timeAvg': '108',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0600',
#    'routeName': '서울양양선',
#    'updownTypeCode': 'S',
#    'vdsId': '0600VDS00002',
#    'trafficAmout': '51',
#    'shareRatio': '36',
#    'conzoneId': '0600CZS030',
#    'conzoneName': '덕소삼패IC-미사IC',
#    'stdDate': '20220816',
#    'speed': '33',
#    'timeAvg': '220',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '0600',
#    'routeName': '서울양양선',
#    'updownTypeCode': 'S',
#    'vdsId': '0600VDS00037',
#    'trafficAmout': '45',
#    'shareRatio': '40',
#    'conzoneId': '0600CZS090',
#    'conzoneName': '남춘천IC-강촌IC',
#    'stdDate': '20220816',
#    'speed': '40',
#    'timeAvg': '86',
#    'grade': '2'},
#   {'stdHour': '1608',
#    'routeNo': '1000',
#    'routeName': '수도권제1순환선',
#    'updownTypeCode': 'E',
#    'vdsId': '1000VDE01900',
#    'trafficAmout': '61',
#    'shareRatio': '41',
#    'conzoneId': '1000CZE050',
#    'conzoneName': '서하남IC-하남JC',
#    'stdDate': '20220816',
#    'speed': '29',
#    'timeAvg': '114',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '1000',
#    'routeName': '수도권제1순환선',
#    'updownTypeCode': 'E',
#    'vdsId': '1000VDE02000',
#    'trafficAmout': '61',
#    'shareRatio': '41',
#    'conzoneId': '1000CZE050',
#    'conzoneName': '서하남IC-하남JC',
#    'stdDate': '20220816',
#    'speed': '29',
#    'timeAvg': '183',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '1000',
#    'routeName': '수도권제1순환선',
#    'updownTypeCode': 'E',
#    'vdsId': '1000VDE02250',
#    'trafficAmout': '138',
#    'shareRatio': '0',
#    'conzoneId': '1000CZE060',
#    'conzoneName': '하남JC-상일IC',
#    'stdDate': '20220816',
#    'speed': '33',
#    'timeAvg': '178',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '1000',
#    'routeName': '수도권제1순환선',
#    'updownTypeCode': 'E',
#    'vdsId': '1000VDE02300',
#    'trafficAmout': '138',
#    'shareRatio': '0',
#    'conzoneId': '1000CZE060',
#    'conzoneName': '하남JC-상일IC',
#    'stdDate': '20220816',
#    'speed': '33',
#    'timeAvg': '90',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '1000',
#    'routeName': '수도권제1순환선',
#    'updownTypeCode': 'S',
#    'vdsId': '1000VDS01851',
#    'trafficAmout': '36',
#    'shareRatio': '33',
#    'conzoneId': '1000CZS050',
#    'conzoneName': '하남JC-서하남IC',
#    'stdDate': '20220816',
#    'speed': '17',
#    'timeAvg': '50',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '1000',
#    'routeName': '수도권제1순환선',
#    'updownTypeCode': 'S',
#    'vdsId': '1000VDS01852',
#    'trafficAmout': '33',
#    'shareRatio': '32',
#    'conzoneId': '1000CZS050',
#    'conzoneName': '하남JC-서하남IC',
#    'stdDate': '20220816',
#    'speed': '18',
#    'timeAvg': '99',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '1000',
#    'routeName': '수도권제1순환선',
#    'updownTypeCode': 'S',
#    'vdsId': '1000VDS01900',
#    'trafficAmout': '36',
#    'shareRatio': '33',
#    'conzoneId': '1000CZS050',
#    'conzoneName': '하남JC-서하남IC',
#    'stdDate': '20220816',
#    'speed': '17',
#    'timeAvg': '162',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '1000',
#    'routeName': '수도권제1순환선',
#    'updownTypeCode': 'S',
#    'vdsId': '1000VDS02000',
#    'trafficAmout': '60',
#    'shareRatio': '50',
#    'conzoneId': '1000CZS050',
#    'conzoneName': '하남JC-서하남IC',
#    'stdDate': '20220816',
#    'speed': '17',
#    'timeAvg': '320',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '1000',
#    'routeName': '수도권제1순환선',
#    'updownTypeCode': 'S',
#    'vdsId': '1000VDS06600',
#    'trafficAmout': '68',
#    'shareRatio': '28',
#    'conzoneId': '1000CZS360',
#    'conzoneName': '평촌IC-산본IC',
#    'stdDate': '20220816',
#    'speed': '34',
#    'timeAvg': '292',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '1100',
#    'routeName': '제2경인선',
#    'updownTypeCode': 'E',
#    'vdsId': '1100VDE00400',
#    'trafficAmout': '44',
#    'shareRatio': '40',
#    'conzoneId': '1100CZE030',
#    'conzoneName': '문학IC-남동IC',
#    'stdDate': '20220816',
#    'speed': '26',
#    'timeAvg': '82',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '1100',
#    'routeName': '제2경인선',
#    'updownTypeCode': 'E',
#    'vdsId': '1100VDE00600',
#    'trafficAmout': '42',
#    'shareRatio': '23',
#    'conzoneId': '1100CZE030',
#    'conzoneName': '문학IC-남동IC',
#    'stdDate': '20220816',
#    'speed': '35',
#    'timeAvg': '96',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '1100',
#    'routeName': '제2경인선',
#    'updownTypeCode': 'E',
#    'vdsId': '1100VDE00700',
#    'trafficAmout': '57',
#    'shareRatio': '57',
#    'conzoneId': '1100CZE030',
#    'conzoneName': '문학IC-남동IC',
#    'stdDate': '20220816',
#    'speed': '22',
#    'timeAvg': '113',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '1102',
#    'routeName': '인천대교선',
#    'updownTypeCode': 'S',
#    'vdsId': '1102VDS01500',
#    'trafficAmout': '33',
#    'shareRatio': '7',
#    'conzoneId': '1102CZS030',
#    'conzoneName': '인천대교TG-연수JC',
#    'stdDate': '20220816',
#    'speed': '25',
#    'timeAvg': '140',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '1200',
#    'routeName': '경인선',
#    'updownTypeCode': 'S',
#    'vdsId': '1200VDS01200',
#    'trafficAmout': '73',
#    'shareRatio': '22',
#    'conzoneId': '1200CZS040',
#    'conzoneName': '부평IC-서인천IC',
#    'stdDate': '20220816',
#    'speed': '40',
#    'timeAvg': '161',
#    'grade': '2'},
#   {'stdHour': '1608',
#    'routeNo': '1200',
#    'routeName': '경인선',
#    'updownTypeCode': 'S',
#    'vdsId': '1200VDS01300',
#    'trafficAmout': '73',
#    'shareRatio': '22',
#    'conzoneId': '1200CZS040',
#    'conzoneName': '부평IC-서인천IC',
#    'stdDate': '20220816',
#    'speed': '40',
#    'timeAvg': '107',
#    'grade': '2'},
#   {'stdHour': '1608',
#    'routeNo': '1200',
#    'routeName': '경인선',
#    'updownTypeCode': 'S',
#    'vdsId': '1200VDS01400',
#    'trafficAmout': '70',
#    'shareRatio': '26',
#    'conzoneId': '1200CZS040',
#    'conzoneName': '부평IC-서인천IC',
#    'stdDate': '20220816',
#    'speed': '37',
#    'timeAvg': '73',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '1710',
#    'routeName': '용인서울선',
#    'updownTypeCode': 'E',
#    'vdsId': '1710VDE00030',
#    'trafficAmout': '36',
#    'shareRatio': '19',
#    'conzoneId': '1710CZE050',
#    'conzoneName': '금광지하차도북측-광교IC',
#    'stdDate': '20220816',
#    'speed': '27',
#    'timeAvg': '77',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '1710',
#    'routeName': '용인서울선',
#    'updownTypeCode': 'E',
#    'vdsId': '1710VDE00040',
#    'trafficAmout': '29',
#    'shareRatio': '41',
#    'conzoneId': '1710CZE060',
#    'conzoneName': '광교IC-서수지IC',
#    'stdDate': '20220816',
#    'speed': '8',
#    'timeAvg': '493',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '1710',
#    'routeName': '용인서울선',
#    'updownTypeCode': 'E',
#    'vdsId': '1710VDE00050',
#    'trafficAmout': '44',
#    'shareRatio': '18',
#    'conzoneId': '1710CZE060',
#    'conzoneName': '광교IC-서수지IC',
#    'stdDate': '20220816',
#    'speed': '28',
#    'timeAvg': '186',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '4000',
#    'routeName': '봉담동탄선',
#    'updownTypeCode': 'S',
#    'vdsId': '4000VDS00008',
#    'trafficAmout': '44',
#    'shareRatio': '32',
#    'conzoneId': '4000CZS020',
#    'conzoneName': '동탄JC-북오산IC',
#    'stdDate': '20220816',
#    'speed': '35',
#    'timeAvg': '95',
#    'grade': '3'},
#   {'stdHour': '1608',
#    'routeNo': '4000',
#    'routeName': '봉담동탄선',
#    'updownTypeCode': 'S',
#    'vdsId': '4000VDS00009',
#    'trafficAmout': '29',
#    'shareRatio': '42',
#    'conzoneId': '4000CZS020',
#    'conzoneName': '동탄JC-북오산IC',
#    'stdDate': '20220816',
#    'speed': '14',
#    'timeAvg': '263',
#    'grade': '3'}],
#  'count': 101,
#  'message': '인증키가 유효합니다.',
#  'code': 'SUCCESS'}

# %%
from pandas.io.json import json_normalize

# %%
# info = json.loads(data)

df=json_normalize(data['list'])
df
# Out:
# C:\Users\sju02\AppData\Local\Temp\ipykernel_23712\1734257214.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df=json_normalize(data['list'])
#     stdHour routeNo routeName updownTypeCode         vdsId trafficAmout  \
# 0      1608    0010       경부선              E  0010VDE28900          119
# 1      1608    0010       경부선              E  0010VDE29000          112
# 2      1608    0010       경부선              E  0010VDE29200           67
# 3      1608    0010       경부선              E  0010VDE29300           96
# 4      1608    0010       경부선              E  0010VDE29400           96
# ..      ...     ...       ...            ...           ...          ...
# 96     1608    1710     용인서울선              E  1710VDE00030           36
# 97     1608    1710     용인서울선              E  1710VDE00040           29
# 98     1608    1710     용인서울선              E  1710VDE00050           44
# 99     1608    4000     봉담동탄선              S  4000VDS00008           44
# 100    1608    4000     봉담동탄선              S  4000VDS00009           29
#
#     shareRatio   conzoneId    conzoneName   stdDate speed timeAvg grade
# 0           46  0010CZE405    남사진위IC-오산IC  20220816    33     187     3
# 1           36  0010CZE405    남사진위IC-오산IC  20220816    37     109     3
# 2           39  0010CZE405    남사진위IC-오산IC  20220816    35     106     3
# 3           28  0010CZE410      오산IC-동탄JC  20220816    34     139     3
# 4           28  0010CZE410      오산IC-동탄JC  20220816    34      89     3
# ..         ...         ...            ...       ...   ...     ...   ...
# 96          19  1710CZE050  금광지하차도북측-광교IC  20220816    27      77     3
# 97          41  1710CZE060     광교IC-서수지IC  20220816     8     493     3
# 98          18  1710CZE060     광교IC-서수지IC  20220816    28     186     3
# 99          32  4000CZS020     동탄JC-북오산IC  20220816    35      95     3
# 100         42  4000CZS020     동탄JC-북오산IC  20220816    14     263     3
#
# [101 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   stdHour         101 non-null    object
#  1   routeNo         101 non-null    object
#  2   routeName       101 non-null    object
#  3   updownTypeCode  101 non-null    object
#  4   vdsId           101 non-null    object
#  5   trafficAmout    101 non-null    object
#  6   shareRatio      101 non-null    object
#  7   conzoneId       101 non-null    object
#  8   conzoneName     101 non-null    object
#  9   stdDate         101 non-null    object
#  10  speed           101 non-null    object
#  11  timeAvg         101 non-null    object
#  12  grade           101 non-null    object
# dtypes: object(13)
# memory usage: 10.4+ KB
